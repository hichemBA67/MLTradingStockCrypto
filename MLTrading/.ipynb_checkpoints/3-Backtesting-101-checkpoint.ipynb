# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
from pandas_datareader.data import DataReader
import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Execution

# %%
start_date = "2017-01-01"
end_date = "2022-10-14"
symbol = "SPY"

df = DataReader(name=symbol, data_source='yahoo', start=start_date, end=end_date)
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2017-01-03  225.830002  223.880005  225.039993  225.240005   91366500.0
# 2017-01-04  226.750000  225.610001  225.619995  226.580002   78744400.0
# 2017-01-05  226.580002  225.479996  226.270004  226.399994   78379000.0
# 2017-01-06  227.750000  225.899994  226.529999  227.210007   71559900.0
# 2017-01-09  227.070007  226.419998  226.910004  226.460007   46939700.0
# ...                ...         ...         ...         ...          ...
# 2022-10-10  364.209991  357.670013  363.959991  360.019989   76042800.0
# 2022-10-11  363.029999  355.709991  358.239990  357.739990   92482800.0
# 2022-10-12  359.820007  356.299988  358.170013  356.559998   76991800.0
# 2022-10-13  367.510010  348.109985  349.209991  365.970001  147254500.0
# 2022-10-14  370.260010  356.959991  368.549988  357.630005  123625000.0
#
#              Adj Close
# Date
# 2017-01-03  203.788025
# 2017-01-04  205.000427
# 2017-01-05  204.837555
# 2017-01-06  205.570419
# 2017-01-09  204.891861
# ...                ...
# 2022-10-10  360.019989
# 2022-10-11  357.739990
# 2022-10-12  356.559998
# 2022-10-13  365.970001
# 2022-10-14  357.630005
#
# [1457 rows x 6 columns]

# %% [markdown]
# ### Feature Adjustment

# %%
# Add moving averages
df["MA_12"] = df["Adj Close"].rolling(window=12).mean()
df["MA_21"] = df["Adj Close"].rolling(window=21).mean()

df.loc[df["MA_12"] > df["MA_21"], "Signal"] = 1
df.loc[df["MA_12"] <= df["MA_21"], "Signal"] = 1

df["Signal"] = df["Signal"].shift(1)
df.head(3)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-03  225.830002  223.880005  225.039993  225.240005  91366500.0
# 2017-01-04  226.750000  225.610001  225.619995  226.580002  78744400.0
# 2017-01-05  226.580002  225.479996  226.270004  226.399994  78379000.0
#
#              Adj Close  MA_12  MA_21  Signal  lrets_bench  lrets_prod_bench  \
# Date
# 2017-01-03  203.788025    NaN    NaN     NaN          NaN               NaN
# 2017-01-04  205.000427    NaN    NaN     NaN     0.005932          0.005932
# 2017-01-05  204.837555    NaN    NaN     NaN    -0.000795          0.005137
#
#             prod_bench
# Date
# 2017-01-03         NaN
# 2017-01-04    0.005949
# 2017-01-05    0.005150

# %%
# Add returns
df["lrets_bench"] = np.log(df["Adj Close"] / df["Adj Close"].shift(1))
df["lrets_prod_bench"] = df["lrets_bench"].cumsum()
df["prod_bench"] = np.exp(df["lrets_prod_bench"]) - 1
df.head(3)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-01-03  225.830002  223.880005  225.039993  225.240005  91366500.0
# 2017-01-04  226.750000  225.610001  225.619995  226.580002  78744400.0
# 2017-01-05  226.580002  225.479996  226.270004  226.399994  78379000.0
#
#              Adj Close  MA_12  MA_21  Signal  lrets_bench  lrets_prod_bench  \
# Date
# 2017-01-03  203.788025    NaN    NaN     NaN          NaN               NaN
# 2017-01-04  205.000427    NaN    NaN     NaN     0.005932          0.005932
# 2017-01-05  204.837555    NaN    NaN     NaN    -0.000795          0.005137
#
#             prod_bench
# Date
# 2017-01-03         NaN
# 2017-01-04    0.005949
# 2017-01-05    0.005150

# %%
# Add stategy returns
df["lrets_strat"] = np.log(df["Open"].shift(-1) / df["Open"] * df["Signal"])
df["lrets_prod_strat"] = df["lrets_strat"].cumsum()
df["prod_strat"] = np.exp(df["lrets_prod_strat"]) - 1

df.tail(3)
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-10-12  359.820007  356.299988  358.170013  356.559998   76991800.0
# 2022-10-13  367.510010  348.109985  349.209991  365.970001  147254500.0
# 2022-10-14  370.260010  356.959991  368.549988  357.630005  123625000.0
#
#              Adj Close       MA_12       MA_21  Signal  lrets_bench  \
# Date
# 2022-10-12  356.559998  365.488332  371.878081     1.0    -0.003304
# 2022-10-13  365.970001  365.704165  370.591620     1.0     0.026049
# 2022-10-14  357.630005  364.629166  369.120476     1.0    -0.023052
#
#             lrets_prod_bench  prod_bench  lrets_strat  lrets_prod_strat  \
# Date
# 2022-10-12          0.559422    0.749661    -0.025334          0.427996
# 2022-10-13          0.585471    0.795837     0.053903          0.481899
# 2022-10-14          0.562419    0.754912          NaN               NaN
#
#             prod_strat
# Date
# 2022-10-12    0.534180
# 2022-10-13    0.619146
# 2022-10-14         NaN

# %%
# Remove NaN's
df.dropna(inplace=True)

# %%
# Review DataFrame
print("DF Length: ",len(df))
# Out:
# DF Length: 1435

# %%
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2017-02-02  228.100006  226.820007  227.619995  227.770004  69657600.0
# 2017-02-03  229.550003  228.460007  228.820007  229.339996  80563200.0
# 2017-02-06  229.330002  228.539993  228.869995  228.929993  57790100.0
# 2017-02-07  229.660004  228.720001  229.380005  228.940002  57931200.0
# 2017-02-08  229.389999  228.309998  228.940002  229.240005  51566200.0
#
#              Adj Close       MA_12       MA_21  Signal  lrets_bench  \
# Date
# 2017-02-02  206.077087  205.945137  205.575592     1.0     0.000659
# 2017-02-03  207.497589  206.140416  205.694505     1.0     0.006869
# 2017-02-06  207.126602  206.368113  205.803507     1.0    -0.001790
# 2017-02-07  207.135666  206.533989  205.878042     1.0     0.000044
# 2017-02-08  207.407074  206.766969  205.997814     1.0     0.001309
#
#             lrets_prod_bench  prod_bench  lrets_strat  lrets_prod_strat  \
# Date
# 2017-02-02          0.011170    0.011233     0.005258          0.005258
# 2017-02-03          0.018039    0.018203     0.000218          0.005477
# 2017-02-06          0.016250    0.016383     0.002226          0.007702
# 2017-02-07          0.016294    0.016427    -0.001920          0.005782
# 2017-02-08          0.017603    0.017759     0.001310          0.007092
#
#             prod_strat
# Date
# 2017-02-02    0.005272
# 2017-02-03    0.005492
# 2017-02-06    0.007732
# 2017-02-07    0.005799
# 2017-02-08    0.007117

# %% [markdown]
# ### Plot results

# %%
# Show graph
fig = plt.figure(figsize=(15,8))
plt.plot(df["prod_bench"])
plt.plot(df["prod_strat"])
plt.show()

# %% [markdown]
# ### Metrics

# %%
# Calculate returns
print("Benchmark Returns: ", df["prod_bench"].iloc[-1])
print("Strategy Returns: ", df["prod_strat"].iloc[-1])
# Out:
# Benchmark Returns:  0.7958366366035343
# Strategy Returns:  0.619145926100322

# %%
# Calculate Sharpe
def calculate_sharpe(returns):
    N = 255
    rf = 0.00
    SQRTN = np.sqrt(N)
    mean = returns.mean() * N
    sigma = returns.std() * SQRTN
    sharpe = round((mean - rf) / sigma, 3)
    return sharpe

# %%
# Show Sharpe
bench_sharpe = calculate_sharpe(df["lrets_bench"].values)
strat_sharpe = calculate_sharpe(df["lrets_strat"].values)

print("Benchmark Sharpe: ", bench_sharpe)
print("Strategy Sharpe: ", strat_sharpe)
# Out:
# Benchmark Sharpe:  0.51
# Strategy Sharpe:  0.457
